# %% [markdown]
# Run Query: Find all the tracks whose name starts with 'All'. **How many total records there are for this query?**

# %%
# %load_ext sql
# %sql postgresql://ds22m031:SVD489JK@mds-dsi-db.postgres.database.azure.com/music-store

# %%
#find all the tracks starts with ALL
# %sql SELECT * FROM tracks WHERE name LIKE 'All%'
# Out:
#  * postgresql://ds22m031:***@mds-dsi-db.postgres.database.azure.com/music-store
# 15 rows affected.
# [(38, 'All I Really Want', 6, 1, 1, 'Alanis Morissette & Glenn Ballard', 284891, 9375567, Decimal('0.99')),
#  (134, 'All For You', 14, 1, 3, None, 235833, 7726948, Decimal('0.99')),
#  (385, 'All Star', 33, 1, 7, 'Nando Reis', 176326, 5891697, Decimal('0.99')),
#  (1009, 'All My Life', 81, 1, 4, 'Foo Fighters', 263653, 8665545, Decimal('0.99')),
#  (1608, 'All My Love', 130, 1, 1, 'Robert Plant & John Paul Jones', 356284, 11684862, Decimal('0.99')),
#  (1892, 'All Within My Hands', 155, 1, 3, 'Bob Rock/James Hetfield/Kirk Hammett/Lars Ulrich', 527986, 17162741, Decimal('0.99')),
#  (2192, 'All or None', 180, 1, 1, 'Stone Gossard', 277655, 9104728, Decimal('0.99')),
#  (2274, 'All Dead, All Dead', 186, 1, 1, 'May', 190119, 6144878, Decimal('0.99')),
#  (2888, 'All the Best Cowboys Have Daddy Issues', 230, 3, 19, None, 2555492, 211743651, Decimal('1.99')),
# ...

# %% [markdown]
# Run Query: Find all the customer emails that start with "J" and are from gmail.com.

# %%
#Find all the customer emails that start with "J"
# %sql SELECT email FROM customers WHERE (email LIKE 'j%' or email LIKE 'J%') and email LIKE '%@gmail.com'
# Out:
#  * postgresql://ds22m031:***@mds-dsi-db.postgres.database.azure.com/music-store
# 1 rows affected.
# [('jubarnett@gmail.com',)]

# %% [markdown]
# Run Query: Find the albums with 12 or more tracks.

# %%
#find all the albums with 12 or more tracks
# %sql SELECT * FROM albums WHERE id IN (SELECT album_id FROM tracks GROUP BY album_id HAVING count(*) > 12)
# Out:
#  * postgresql://ds22m031:***@mds-dsi-db.postgres.database.azure.com/music-store
# 129 rows affected.
# [(5, 'Big Ones', 3),
#  (6, 'Jagged Little Pill', 4),
#  (8, 'Warner 25 Anos', 6),
#  (10, 'Audioslave', 8),
#  (14, 'Alcohol Fueled Brewtality Live! [Disc 1]', 11),
#  (18, 'Body Count', 13),
#  (21, 'Prenda Minha', 16),
#  (23, 'Minha Historia', 17),
#  (24, 'Afrociberdelia', 18),
#  (25, 'Da Lama Ao Caos', 18),
#  (26, 'Acústico MTV [Live]', 19),
#  (27, 'Cidade Negra - Hits', 19),
#  (29, 'Axé Bahia 2001', 21),
#  (30, 'BBC Sessions [Disc 1] [Live]', 22),
#  (32, 'Carnaval 2001', 21),
#  (33, 'Chill: Brazil (Disc 1)', 24),
#  (34, 'Chill: Brazil (Disc 2)', 6),
#  (36, 'Greatest Hits II', 51),
#  (37, 'Greatest Kiss', 52),
#  (39, 'International Superhits', 54),
#  (41, 'Meus Momentos', 56),
#  (42, 'Minha História', 57),
#  (45, 'Sambas De Enredo 2001', 21),
#  (46, 'Supernatural', 59),
#  (47, 'The Best of Ed Motta', 37),
#  (48, 'The Essential Miles Davis [Disc 1]', 68),
# ...

# %% [markdown]
# Create a list of album titles and the unit prices for the artist "Audioslave".

# %%
#Create a list of album titles and the unit prices for the artist "Audioslave". 

# %sql SELECT DISTINCT albums.title, tracks.unit_price FROM albums INNER JOIN tracks ON albums.id = tracks.album_id WHERE albums.artist_id = (SELECT id FROM artists WHERE name = 'Audioslave')
# Out:
#  * postgresql://ds22m031:***@mds-dsi-db.postgres.database.azure.com/music-store
# 3 rows affected.
# [('Revelations', Decimal('0.99')),
#  ('Out Of Exile', Decimal('0.99')),
#  ('Audioslave', Decimal('0.99'))]

# %% [markdown]
# Using a subquery, find the names of all the tracks for the album "Californication".

# %%
# %sql SELECT name FROM tracks WHERE album_id = (SELECT id FROM albums WHERE title = 'Californication')
# Out:
#  * postgresql://ds22m031:***@mds-dsi-db.postgres.database.azure.com/music-store
# 15 rows affected.
# [('Around The World',),
#  ('Parallel Universe',),
#  ('Scar Tissue',),
#  ('Otherside',),
#  ('Get On Top',),
#  ('Californication',),
#  ('Easily',),
#  ('Porcelain',),
#  ('Emit Remmus',),
#  ('I Like Dirt',),
#  ('This Velvet Glove',),
#  ('Savior',),
#  ('Purple Stain',),
#  ('Right On Time',),
#  ("Road Trippin'",)]

# %% [markdown]
# Find the total number of invoices for each customer along with the customer's full name, city and email.

# %%
#create a view of all the tracks that are longer than 5 minutes

# %sql CREATE VIEW costumer_Invoices AS SELECT customers.first_name || ' ' || customers.last_name AS full_name, customers.city, customers.email, count(invoices.id) AS total_invoices FROM customers INNER JOIN invoices ON customers.id = invoices.customer_id GROUP BY customers.id
# %sql SELECT * from costumer_Invoices
# Out:
#  * postgresql://ds22m031:***@mds-dsi-db.postgres.database.azure.com/music-store
# (psycopg2.errors.DuplicateTable) relation "costumer_invoices" already exists
#
# [SQL: CREATE VIEW costumer_Invoices AS SELECT customers.first_name || ' ' || customers.last_name AS full_name, customers.city, customers.email, count(invoices.id) AS total_invoices FROM customers INNER JOIN invoices ON customers.id = invoices.customer_id GROUP BY customers.id]
# (Background on this error at: https://sqlalche.me/e/14/f405)
#  * postgresql://ds22m031:***@mds-dsi-db.postgres.database.azure.com/music-store
# 59 rows affected.
# [('Robert Brown', 'Toronto', 'robbrown@shaw.ca', 7),
#  ('Steve Murray', 'Edinburgh', 'steve.murray@yahoo.uk', 7),
#  ('Bjørn Hansen', 'Oslo', 'bjorn.hansen@yahoo.no', 7),
#  ('João Fernandes', 'Lisbon', 'jfernandes@yahoo.pt', 7),
#  ('Joakim Johansson', 'Stockholm', 'joakim.johansson@yahoo.se', 7),
#  ('Emma Jones', 'London', 'emma_jones@hotmail.com', 7),
# ...

# %%
# %sql SELECT email from costumer_Invoices WHERE full_name LIKE 'František Wichterlová'
# Out:
#  * postgresql://ds22m031:***@mds-dsi-db.postgres.database.azure.com/music-store
# 1 rows affected.
# [('frantisekw@jetbrains.com',)]

# %% [markdown]
# Retrieve the track name, album, artistID, and trackID for all the albums.

# %%
#find the track name, album, artistID, and trackID for all the albums.
# %sql SELECT tracks.name, albums.title, albums.artist_id, tracks.id FROM tracks INNER JOIN albums ON tracks.album_id = albums.id
# Out:
#  * postgresql://ds22m031:***@mds-dsi-db.postgres.database.azure.com/music-store
# 3503 rows affected.
# [('For Those About To Rock (We Salute You)', 'For Those About To Rock We Salute You', 1, 1),
#  ('Balls to the Wall', 'Balls to the Wall', 2, 2),
#  ('Fast As a Shark', 'Restless and Wild', 2, 3),
#  ('Restless and Wild', 'Restless and Wild', 2, 4),
#  ('Princess of the Dawn', 'Restless and Wild', 2, 5),
#  ('Put The Finger On You', 'For Those About To Rock We Salute You', 1, 6),
#  ("Let's Get It Up", 'For Those About To Rock We Salute You', 1, 7),
#  ('Inject The Venom', 'For Those About To Rock We Salute You', 1, 8),
#  ('Snowballed', 'For Those About To Rock We Salute You', 1, 9),
#  ('Evil Walks', 'For Those About To Rock We Salute You', 1, 10),
#  ('C.O.D.', 'For Those About To Rock We Salute You', 1, 11),
#  ('Breaking The Rules', 'For Those About To Rock We Salute You', 1, 12),
#  ('Night Of The Long Knives', 'For Those About To Rock We Salute You', 1, 13),
# ...

# %% [markdown]
# What is the song title of trackID 12 from the "For Those About to Rock We Salute You" ?

# %%
#find What is the song title of trackID 12 from the album  "For Those About to Rock We Salute You" ?
# %sql SELECT tracks.name FROM tracks INNER JOIN albums ON tracks.album_id = albums.id WHERE tracks.id = 12 AND albums.title = 'For Those About To Rock We Salute You'
# Out:
#  * postgresql://ds22m031:***@mds-dsi-db.postgres.database.azure.com/music-store
# 1 rows affected.
# [('Breaking The Rules',)]

# %% [markdown]
# Retrieve a list with the managers last name, and the last name of the employees who report to him or her. **Who are the reports for the manager named Mitchell?**

# %%
# %sql CREATE VIEW Manager AS SELECT employees.last_name, employees.reports_to FROM employees WHERE employees.reports_to = (SELECT id FROM employees WHERE last_name = 'Mitchell')
# %sql SELECT employees.last_name, Manager.last_name FROM Manager, employees WHERE Manager.reports_to = employees.id
# Out:
#  * postgresql://ds22m031:***@mds-dsi-db.postgres.database.azure.com/music-store
# (psycopg2.errors.DuplicateTable) relation "manager" already exists
#
# [SQL: CREATE VIEW Manager AS SELECT employees.last_name, employees.reports_to FROM employees WHERE employees.reports_to = (SELECT id FROM employees WHERE last_name = 'Mitchell' )]
# (Background on this error at: https://sqlalche.me/e/14/f405)
#  * postgresql://ds22m031:***@mds-dsi-db.postgres.database.azure.com/music-store
# 2 rows affected.
# [('Mitchell', 'King'), ('Mitchell', 'Callahan')]

# %% [markdown]
# Find the name and ID of the artists who do not have albums.

# %%
#Find the name and ID of the artists who do not have albums.
# %sql SELECT artists.name, artists.id FROM artists WHERE artists.id NOT IN (SELECT artist_id FROM albums)
# Out:
#  * postgresql://ds22m031:***@mds-dsi-db.postgres.database.azure.com/music-store
# 71 rows affected.
# [('Milton Nascimento & Bebeto', 25),
#  ('Azymuth', 26),
#  ('João Gilberto', 28),
#  ('Bebel Gilberto', 29),
#  ('Jorge Vercilo', 30),
#  ('Baby Consuelo', 31),
#  ('Ney Matogrosso', 32),
#  ('Luiz Melodia', 33),
#  ('Nando Reis', 34),
#  ('Pedro Luís & A Parede', 35),
#  ('Banda Black Rio', 38),
#  ('Fernanda Porto', 39),
#  ('Os Cariocas', 40),
#  ('A Cor Do Som', 43),
#  ('Kid Abelha', 44),
#  ('Sandra De Sá', 45),
#  ('Hermeto Pascoal', 47),
#  ('Barão Vermelho', 48),
#  ('Edson, DJ Marky & DJ Patife Featuring Fernanda Porto', 49),
#  ('Santana Feat. Dave Matthews', 60),
#  ('Santana Feat. Everlast', 61),
#  ('Santana Feat. Rob Thomas', 62),
#  ('Santana Feat. Lauryn Hill & Cee-Lo', 63),
#  ('Santana Feat. The Project G&B', 64),
#  ('Santana Feat. Maná', 65),
#  ('Santana Feat. Eagle-Eye Cherry', 66),
#  ('Santana Feat. Eric Clapton', 67),
# ...

# %% [markdown]
# Use a UNION to create a list of all the employee's and customer's first names and last names ordered by the last name in descending order. **Determine what is the last name of the 6th record** Remember to order things in descending order to be sure to get the correct answer.

# %%
#Use a UNION to create a list of all the employee's and customer's first names and last names ordered by the last name in descending order. 
# %sql Create VIEW UnionView as  SELECT first_name, last_name FROM employees UNION SELECT first_name, last_name FROM customers ORDER BY last_name 
#get last name of the 6th employee
# %sql SELECT last_name FROM UnionView LIMIT 1 OFFSET 5
# Out:
#  * postgresql://ds22m031:***@mds-dsi-db.postgres.database.azure.com/music-store
# (psycopg2.errors.DuplicateTable) relation "unionview" already exists
#
# [SQL: Create VIEW UnionView as SELECT first_name, last_name FROM employees UNION SELECT first_name, last_name FROM customers ORDER BY last_name]
# (Background on this error at: https://sqlalche.me/e/14/f405)
#  * postgresql://ds22m031:***@mds-dsi-db.postgres.database.azure.com/music-store
# 1 rows affected.
# [('Taylor',)]

# %% [markdown]
# See if there are any customers who have a different city listed in their billing city versus their customer city.

# %%
#are any customers who have a different city listed in their billing city versus their customer city.
# %sql SELECT * FROM customers WHERE city != billing_city
# Out:
#  * postgresql://ds22m031:***@mds-dsi-db.postgres.database.azure.com/music-store
# (psycopg2.errors.UndefinedColumn) column "billing_city" does not exist
# LINE 1: SELECT * FROM customers WHERE city != billing_city
#                                               ^
#
# [SQL: SELECT * FROM customers WHERE city != billing_city]
# (Background on this error at: https://sqlalche.me/e/14/f405)

# %%
# %sql SELECT * FROM customers JOIN invoices ON customers.id = customer_id WHERE customers.city != invoices.billing_city;
