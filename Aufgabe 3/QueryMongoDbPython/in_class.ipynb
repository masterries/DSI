# %%
# !pip install pymongo[srv]
#https://pymongo.readthedocs.io/en/stable/tutorial.html
# Out:
# Collecting pymongo[srv]
#   Downloading pymongo-4.3.3-cp39-cp39-win_amd64.whl (382 kB)
#      ------------------------------------- 382.5/382.5 kB 12.0 MB/s eta 0:00:00
# Collecting dnspython<3.0.0,>=1.16.0
#   Downloading dnspython-2.2.1-py3-none-any.whl (269 kB)
#      ------------------------------------- 269.1/269.1 kB 16.2 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.2.1 pymongo-4.3.3

# %% [markdown]
# ## In class example of using mongodb

# %%
import pymongo
import ssl
from pymongo import MongoClient
import pandas as pd
import numpy as np


client = MongoClient('mongodb+srv://student:nRfKfRqEtgWvznFD@cluster0.gu4ru.mongodb.net')

# %%
db = client.get_database('sample_training')

# %%
trip = db.trips.find()

# %% [markdown]
# Query result is always a cursor! - Not the requested

# %%
type(trip)
# Out:
# pymongo.cursor.Cursor

# %% [markdown]
# Let's evaluate response as list

# %%
#evaluate request
list(trip)
# Out:
# [{'_id': ObjectId('572bb8222b288919b68abf5c'),
#   'tripduration': 589,
#   'start station id': 489,
#   'start station name': '10 Ave & W 28 St',
#   'end station id': 284,
#   'end station name': 'Greenwich Ave & 8 Ave',
#   'bikeid': 21997,
#   'usertype': 'Subscriber',
#   'birth year': 1982,
#   'start station location': {'type': 'Point',
#    'coordinates': [-74.00176802, 40.75066386]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-74.0026376103, 40.7390169121]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 0, 48),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 10, 37)},
#  {'_id': ObjectId('572bb8222b288919b68abf61'),
#   'tripduration': 1376,
#   'start station id': 527,
#   'start station name': 'E 33 St & 2 Ave',
#   'end station id': 259,
#   'end station name': 'South St & Whitehall St',
#   'bikeid': 23933,
#   'usertype': 'Subscriber',
#   'birth year': 1963,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.976056, 40.744023]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-74.01234218, 40.70122128]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 3, 12),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 26, 9)},
#  {'_id': ObjectId('572bb8222b288919b68abf63'),
#   'tripduration': 615,
#   'start station id': 432,
#   'start station name': 'E 7 St & Avenue A',
#   'end station id': 311,
#   'end station name': 'Norfolk St & Broome St',
#   'bikeid': 23993,
#   'usertype': 'Subscriber',
#   'birth year': 1971,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.98379855, 40.72621788]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.98802084, 40.7172274]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 3, 43),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 13, 59)},
#  {'_id': ObjectId('572bb8222b288919b68abf64'),
#   'tripduration': 1770,
#   'start station id': 3226,
#   'start station name': 'W 82 St & Central Park West',
#   'end station id': 509,
#   'end station name': '9 Ave & W 22 St',
#   'bikeid': 22541,
#   'usertype': 'Subscriber',
#   'birth year': 1970,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.97137, 40.78275]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-74.00197139, 40.7454973]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 4, 43),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 34, 14)},
#  {'_id': ObjectId('572bb8222b288919b68abf6e'),
#   'tripduration': 719,
#   'start station id': 3116,
#   'start station name': 'Huron St & Franklin St',
#   'end station id': 3126,
#   'end station name': '44 Dr & Jackson Ave',
#   'bikeid': 16624,
#   'usertype': 'Subscriber',
#   'birth year': 1982,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.95826, 40.73266]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.9432635, 40.74718234]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 10),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 21, 59)},
#  {'_id': ObjectId('572bb8222b288919b68abf71'),
#   'tripduration': 280,
#   'start station id': 512,
#   'start station name': 'W 29 St & 9 Ave',
#   'end station id': 466,
#   'end station name': 'W 25 St & 6 Ave',
#   'bikeid': 23144,
#   'usertype': 'Subscriber',
#   'birth year': 1988,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.99839279, 40.7500727]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.99144871, 40.74395411]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 10, 29),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 15, 9)},
#  {'_id': ObjectId('572bb8222b288919b68abf72'),
#   'tripduration': 937,
#   'start station id': 387,
#   'start station name': 'Centre St & Chambers St',
#   'end station id': 503,
#   'end station name': 'E 20 St & Park Ave',
#   'bikeid': 23650,
#   'usertype': 'Subscriber',
#   'birth year': 1982,
#   'start station location': {'type': 'Point',
#    'coordinates': [-74.0046073, 40.71273266]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.98751968, 40.73827428]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 10, 45),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 26, 22)},
#  {'_id': ObjectId('572bb8222b288919b68abf76'),
#   'tripduration': 1236,
#   'start station id': 3231,
#   'start station name': 'E 67 St & Park Ave',
#   'end station id': 3231,
#   'end station name': 'E 67 St & Park Ave',
#   'bikeid': 16475,
#   'usertype': 'Customer',
#   'birth year': '',
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.96592080593109, 40.76780080148132]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.96592080593109, 40.76780080148132]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 12, 14),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 32, 50)},
#  {'_id': ObjectId('572bb8222b288919b68abf82'),
#   'tripduration': 812,
#   'start station id': 518,
#   'start station name': 'E 39 St & 2 Ave',
#   'end station id': 433,
#   'end station name': 'E 13 St & Avenue A',
#   'bikeid': 14785,
#   'usertype': 'Subscriber',
#   'birth year': 1977,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.9734419, 40.74780373]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.98057249, 40.72955361]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 14, 48),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 28, 21)},
#  {'_id': ObjectId('572bb8222b288919b68abf83'),
#   'tripduration': 285,
#   'start station id': 406,
#   'start station name': 'Hicks St & Montague St',
#   'end station id': 391,
#   'end station name': 'Clark St & Henry St',
#   'bikeid': 18591,
#   'usertype': 'Subscriber',
#   'birth year': 1972,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.99595065, 40.69512845]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.99344559, 40.69760127]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 14, 52),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 19, 37)},
#  {'_id': ObjectId('572bb8222b288919b68abf84'),
#   'tripduration': 967,
#   'start station id': 491,
#   'start station name': 'E 24 St & Park Ave S',
#   'end station id': 495,
#   'end station name': 'W 47 St & 10 Ave',
#   'bikeid': 22478,
#   'usertype': 'Subscriber',
#   'birth year': 1974,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.98602213, 40.74096374]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.99301222, 40.76269882]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 15, 30),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 31, 38)},
#  {'_id': ObjectId('572bb8222b288919b68abf85'),
#   'tripduration': 1092,
#   'start station id': 280,
#   'start station name': 'E 10 St & 5 Ave',
#   'end station id': 527,
#   'end station name': 'E 33 St & 2 Ave',
#   'bikeid': 15713,
#   'usertype': 'Subscriber',
#   'birth year': 1990,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.99510132, 40.73331967]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.976056, 40.744023]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 16, 4),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 34, 16)},
#  {'_id': ObjectId('572bb8222b288919b68abf88'),
#   'tripduration': 931,
#   'start station id': 492,
#   'start station name': 'W 33 St & 7 Ave',
#   'end station id': 405,
#   'end station name': 'Washington St & Gansevoort St',
#   'bikeid': 20258,
#   'usertype': 'Subscriber',
#   'birth year': 1982,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.99093085, 40.75019995]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-74.008119, 40.739323]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 16, 36),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 32, 8)},
#  {'_id': ObjectId('572bb8222b288919b68abf89'),
#   'tripduration': 879,
#   'start station id': 281,
#   'start station name': 'Grand Army Plaza & Central Park S',
#   'end station id': 379,
#   'end station name': 'W 31 St & 7 Ave',
#   'bikeid': 23386,
#   'usertype': 'Subscriber',
#   'birth year': 1981,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.97371465, 40.7643971]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.9916, 40.749156]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 16, 41),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 31, 20)},
#  {'_id': ObjectId('572bb8222b288919b68abf8b'),
#   'tripduration': 2606,
#   'start station id': 307,
#   'start station name': 'Canal St & Rutgers St',
#   'end station id': 489,
#   'end station name': '10 Ave & W 28 St',
#   'bikeid': 21644,
#   'usertype': 'Subscriber',
#   'birth year': 1988,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.98990025, 40.71427487]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-74.00176802, 40.75066386]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 17, 9),
#   'stop time': datetime.datetime(2016, 1, 1, 1, 0, 36)},
#  {'_id': ObjectId('572bb8222b288919b68abf93'),
#   'tripduration': 193,
#   'start station id': 369,
#   'start station name': 'Washington Pl & 6 Ave',
#   'end station id': 335,
#   'end station name': 'Washington Pl & Broadway',
#   'bikeid': 21165,
#   'usertype': 'Subscriber',
#   'birth year': 1986,
#   'start station location': {'type': 'Point',
#    'coordinates': [-74.00026394, 40.73224119]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.99404649, 40.72903917]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 18, 18),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 21, 32)},
#  {'_id': ObjectId('572bb8222b288919b68abf99'),
#   'tripduration': 941,
#   'start station id': 428,
#   'start station name': 'E 3 St & 1 Ave',
#   'end station id': 435,
#   'end station name': 'W 21 St & 6 Ave',
#   'bikeid': 18457,
#   'usertype': 'Subscriber',
#   'birth year': 1982,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.98783413, 40.72467721]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.99415556, 40.74173969]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 19, 33),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 35, 14)},
#  {'_id': ObjectId('572bb8222b288919b68abf9a'),
#   'tripduration': 394,
#   'start station id': 483,
#   'start station name': 'E 12 St & 3 Ave',
#   'end station id': 325,
#   'end station name': 'E 19 St & 3 Ave',
#   'bikeid': 22856,
#   'usertype': 'Subscriber',
#   'birth year': 1994,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.98889957, 40.73223272]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.98473765, 40.73624527]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 19, 37),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 26, 11)},
#  {'_id': ObjectId('572bb8222b288919b68abf9b'),
#   'tripduration': 394,
#   'start station id': 483,
#   'start station name': 'E 12 St & 3 Ave',
#   'end station id': 325,
#   'end station name': 'E 19 St & 3 Ave',
#   'bikeid': 24201,
#   'usertype': 'Subscriber',
#   'birth year': 1994,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.98889957, 40.73223272]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.98473765, 40.73624527]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 19, 37),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 26, 11)},
#  {'_id': ObjectId('572bb8222b288919b68abf9e'),
#   'tripduration': 377,
#   'start station id': 445,
#   'start station name': 'E 10 St & Avenue A',
#   'end station id': 410,
#   'end station name': 'Suffolk St & Stanton St',
#   'bikeid': 22270,
#   'usertype': 'Subscriber',
#   'birth year': 1975,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.98142006, 40.72740794]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.98517977, 40.72066442]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 20, 4),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 26, 21)},
#  {'_id': ObjectId('572bb8222b288919b68abfa4'),
#   'tripduration': 1358,
#   'start station id': 3163,
#   'start station name': 'Central Park West & W 68 St',
#   'end station id': 490,
#   'end station name': '8 Ave & W 33 St',
#   'bikeid': 15535,
#   'usertype': 'Customer',
#   'birth year': '',
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.97782542, 40.7734066]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.993934, 40.751551]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 20, 46),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 43, 24)},
#  {'_id': ObjectId('572bb8222b288919b68abfa6'),
#   'tripduration': 868,
#   'start station id': 279,
#   'start station name': 'Peck Slip & Front St',
#   'end station id': 428,
#   'end station name': 'E 3 St & 1 Ave',
#   'bikeid': 23590,
#   'usertype': 'Subscriber',
#   'birth year': 1996,
#   'start station location': {'type': 'Point',
#    'coordinates': [-74.00167, 40.707873]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.98783413, 40.72467721]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 21, 14),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 35, 42)},
#  {'_id': ObjectId('572bb8222b288919b68abfa8'),
#   'tripduration': 222,
#   'start station id': 358,
#   'start station name': 'Christopher St & Greenwich St',
#   'end station id': 284,
#   'end station name': 'Greenwich Ave & 8 Ave',
#   'bikeid': 17742,
#   'usertype': 'Subscriber',
#   'birth year': 1966,
#   'start station location': {'type': 'Point',
#    'coordinates': [-74.00711384, 40.73291553]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-74.0026376103, 40.7390169121]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 21, 15),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 24, 58)},
#  {'_id': ObjectId('572bb8222b288919b68abfb2'),
#   'tripduration': 552,
#   'start station id': 512,
#   'start station name': 'W 29 St & 9 Ave',
#   'end station id': 482,
#   'end station name': 'W 15 St & 7 Ave',
#   'bikeid': 22831,
#   'usertype': 'Subscriber',
#   'birth year': 1949,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.99839279, 40.7500727]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.99931783, 40.73935542]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 24, 59),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 34, 11)},
#  {'_id': ObjectId('572bb8222b288919b68abfb8'),
#   'tripduration': 1437,
#   'start station id': 3143,
#   'start station name': '5 Ave & E 78 St',
#   'end station id': 524,
#   'end station name': 'W 43 St & 6 Ave',
#   'bikeid': 21638,
#   'usertype': 'Customer',
#   'birth year': '',
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.96388769149779, 40.77682863439968]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.98316936, 40.75527307]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 26, 10),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 50, 8)},
#  {'_id': ObjectId('572bb8222b288919b68abfbb'),
#   'tripduration': 2426,
#   'start station id': 217,
#   'start station name': 'Old Fulton St',
#   'end station id': 263,
#   'end station name': 'Elizabeth St & Hester St',
#   'bikeid': 24152,
#   'usertype': 'Customer',
#   'birth year': '',
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.99383605, 40.70277159]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.996375, 40.71729]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 26, 45),
#   'stop time': datetime.datetime(2016, 1, 1, 1, 7, 11)},
#  {'_id': ObjectId('572bb8222b288919b68abfbc'),
#   'tripduration': 950,
#   'start station id': 3137,
#   'start station name': '5 Ave & E 73 St',
#   'end station id': 522,
#   'end station name': 'E 51 St & Lexington Ave',
#   'bikeid': 15690,
#   'usertype': 'Customer',
#   'birth year': '',
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.96685276, 40.77282817]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.97207836, 40.75714758]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 26, 47),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 42, 37)},
#  {'_id': ObjectId('572bb8222b288919b68abfbd'),
#   'tripduration': 902,
#   'start station id': 3109,
#   'start station name': 'Banker St & Meserole Ave',
#   'end station id': 532,
#   'end station name': 'S 5 Pl & S 4 St',
#   'bikeid': 16316,
#   'usertype': 'Subscriber',
#   'birth year': 1983,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.95621, 40.72606]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.960876, 40.710451]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 26, 51),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 41, 54)},
#  {'_id': ObjectId('572bb8222b288919b68abfbe'),
#   'tripduration': 941,
#   'start station id': 3137,
#   'start station name': '5 Ave & E 73 St',
#   'end station id': 522,
#   'end station name': 'E 51 St & Lexington Ave',
#   'bikeid': 16498,
#   'usertype': 'Customer',
#   'birth year': '',
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.96685276, 40.77282817]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.97207836, 40.75714758]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 26, 55),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 42, 37)},
#  {'_id': ObjectId('572bb8222b288919b68abfc0'),
#   'tripduration': 769,
#   'start station id': 3124,
#   'start station name': '46 Ave & 5 St',
#   'end station id': 3121,
#   'end station name': 'Jackson Ave & 46 Rd',
#   'bikeid': 23963,
#   'usertype': 'Subscriber',
#   'birth year': 1979,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.95451, 40.74731]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.94733276, 40.74524768]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 27, 12),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 40, 1)},
#  {'_id': ObjectId('572bb8222b288919b68abfc1'),
#   'tripduration': 1278,
#   'start station id': 376,
#   'start station name': 'John St & William St',
#   'end station id': 301,
#   'end station name': 'E 2 St & Avenue B',
#   'bikeid': 14659,
#   'usertype': 'Subscriber',
#   'birth year': 1971,
#   'start station location': {'type': 'Point',
#    'coordinates': [-74.00722156, 40.70862144]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.98368779, 40.72217444]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 27, 26),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 48, 45)},
#  {'_id': ObjectId('572bb8222b288919b68abfc3'),
#   'tripduration': 1605,
#   'start station id': 515,
#   'start station name': 'W 43 St & 10 Ave',
#   'end station id': 3002,
#   'end station name': 'South End Ave & Liberty St',
#   'bikeid': 20741,
#   'usertype': 'Customer',
#   'birth year': '',
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.99461843, 40.76009437]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-74.015756, 40.711512]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 27, 36),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 54, 22)},
#  {'_id': ObjectId('572bb8222b288919b68abfc7'),
#   'tripduration': 1417,
#   'start station id': 279,
#   'start station name': 'Peck Slip & Front St',
#   'end station id': 511,
#   'end station name': 'E 14 St & Avenue B',
#   'bikeid': 18489,
#   'usertype': 'Customer',
#   'birth year': '',
#   'start station location': {'type': 'Point',
#    'coordinates': [-74.00167, 40.707873]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.97772429, 40.72938685]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 27, 45),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 51, 23)},
#  {'_id': ObjectId('572bb8222b288919b68abfca'),
#   'tripduration': 305,
#   'start station id': 3164,
#   'start station name': 'Columbus Ave & W 72 St',
#   'end station id': 3162,
#   'end station name': 'W 78 St & Broadway',
#   'bikeid': 15148,
#   'usertype': 'Subscriber',
#   'birth year': 1968,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.97898475, 40.7770575]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.98093133, 40.78339981]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 27, 51),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 32, 56)},
#  {'_id': ObjectId('572bb8222b288919b68abfcd'),
#   'tripduration': 2329,
#   'start station id': 217,
#   'start station name': 'Old Fulton St',
#   'end station id': 263,
#   'end station name': 'Elizabeth St & Hester St',
#   'bikeid': 16158,
#   'usertype': 'Customer',
#   'birth year': '',
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.99383605, 40.70277159]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.996375, 40.71729]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 28, 24),
#   'stop time': datetime.datetime(2016, 1, 1, 1, 7, 14)},
#  {'_id': ObjectId('572bb8222b288919b68abfd5'),
#   'tripduration': 1824,
#   'start station id': 352,
#   'start station name': 'W 56 St & 6 Ave',
#   'end station id': 410,
#   'end station name': 'Suffolk St & Stanton St',
#   'bikeid': 22100,
#   'usertype': 'Subscriber',
#   'birth year': 1992,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.97722479, 40.76340613]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.98517977, 40.72066442]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 29, 13),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 59, 38)},
#  {'_id': ObjectId('572bb8222b288919b68abfda'),
#   'tripduration': 718,
#   'start station id': 449,
#   'start station name': 'W 52 St & 9 Ave',
#   'end station id': 3167,
#   'end station name': 'Amsterdam Ave & W 73 St',
#   'bikeid': 16819,
#   'usertype': 'Subscriber',
#   'birth year': 1972,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.98789473, 40.76461837]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.98093044757842, 40.77966809007312]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 29, 57),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 41, 55)},
#  {'_id': ObjectId('572bb8222b288919b68abfdc'),
#   'tripduration': 494,
#   'start station id': 499,
#   'start station name': 'Broadway & W 60 St',
#   'end station id': 449,
#   'end station name': 'W 52 St & 9 Ave',
#   'bikeid': 22475,
#   'usertype': 'Subscriber',
#   'birth year': 1970,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.98191841, 40.76915505]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.98789473, 40.76461837]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 30, 9),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 38, 23)},
#  {'_id': ObjectId('572bb8222b288919b68abfdf'),
#   'tripduration': 2467,
#   'start station id': 3165,
#   'start station name': 'Central Park West & W 72 St',
#   'end station id': 495,
#   'end station name': 'W 47 St & 10 Ave',
#   'bikeid': 20983,
#   'usertype': 'Customer',
#   'birth year': '',
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.9762057363987, 40.77579376683666]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.99301222, 40.76269882]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 30, 21),
#   'stop time': datetime.datetime(2016, 1, 1, 1, 11, 28)},
#  {'_id': ObjectId('572bb8222b288919b68abfe3'),
#   'tripduration': 738,
#   'start station id': 3177,
#   'start station name': 'W 84 St & Broadway',
#   'end station id': 449,
#   'end station name': 'W 52 St & 9 Ave',
#   'bikeid': 22056,
#   'usertype': 'Subscriber',
#   'birth year': 1991,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.977112, 40.7867947]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.98789473, 40.76461837]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 30, 59),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 43, 18)},
#  {'_id': ObjectId('572bb8222b288919b68abfe5'),
#   'tripduration': 367,
#   'start station id': 445,
#   'start station name': 'E 10 St & Avenue A',
#   'end station id': 433,
#   'end station name': 'E 13 St & Avenue A',
#   'bikeid': 22955,
#   'usertype': 'Subscriber',
#   'birth year': 1977,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.98142006, 40.72740794]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.98057249, 40.72955361]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 31, 8),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 37, 15)},
#  {'_id': ObjectId('572bb8222b288919b68abfe6'),
#   'tripduration': 512,
#   'start station id': 537,
#   'start station name': 'Lexington Ave & E 24 St',
#   'end station id': 482,
#   'end station name': 'W 15 St & 7 Ave',
#   'bikeid': 22158,
#   'usertype': 'Subscriber',
#   'birth year': 1980,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.98409214, 40.74025878]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.99931783, 40.73935542]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 31, 28),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 40)},
#  {'_id': ObjectId('572bb8222b288919b68abfe9'),
#   'tripduration': 592,
#   'start station id': 2021,
#   'start station name': 'W 45 St & 8 Ave',
#   'end station id': 490,
#   'end station name': '8 Ave & W 33 St',
#   'bikeid': 21435,
#   'usertype': 'Customer',
#   'birth year': '',
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.98859651, 40.75929124]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.993934, 40.751551]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 31, 37),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 41, 30)},
#  {'_id': ObjectId('572bb8222b288919b68abfeb'),
#   'tripduration': 1324,
#   'start station id': 515,
#   'start station name': 'W 43 St & 10 Ave',
#   'end station id': 482,
#   'end station name': 'W 15 St & 7 Ave',
#   'bikeid': 17594,
#   'usertype': 'Subscriber',
#   'birth year': 1970,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.99461843, 40.76009437]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.99931783, 40.73935542]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 32, 29),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 54, 33)},
#  {'_id': ObjectId('572bb8222b288919b68abfee'),
#   'tripduration': 582,
#   'start station id': 348,
#   'start station name': 'W Broadway & Spring St',
#   'end station id': 438,
#   'end station name': 'St Marks Pl & 1 Ave',
#   'bikeid': 23744,
#   'usertype': 'Subscriber',
#   'birth year': 1986,
#   'start station location': {'type': 'Point',
#    'coordinates': [-74.00154702, 40.72490985]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.98564945, 40.72779126]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 33, 40),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 43, 22)},
#  {'_id': ObjectId('572bb8222b288919b68abff4'),
#   'tripduration': 267,
#   'start station id': 470,
#   'start station name': 'W 20 St & 8 Ave',
#   'end station id': 405,
#   'end station name': 'Washington St & Gansevoort St',
#   'bikeid': 20647,
#   'usertype': 'Subscriber',
#   'birth year': 1986,
#   'start station location': {'type': 'Point',
#    'coordinates': [-74.00004031, 40.74345335]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-74.008119, 40.739323]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 34, 26),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 38, 53)},
#  {'_id': ObjectId('572bb8222b288919b68abff8'),
#   'tripduration': 574,
#   'start station id': 237,
#   'start station name': 'E 11 St & 2 Ave',
#   'end station id': 410,
#   'end station name': 'Suffolk St & Stanton St',
#   'bikeid': 19079,
#   'usertype': 'Customer',
#   'birth year': '',
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.98672378, 40.73047309]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.98517977, 40.72066442]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 34, 57),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 44, 31)},
#  {'_id': ObjectId('572bb8222b288919b68abffc'),
#   'tripduration': 1237,
#   'start station id': 3092,
#   'start station name': 'Berry St & N 8 St',
#   'end station id': 3066,
#   'end station name': 'Tompkins Ave & Hopkins St',
#   'bikeid': 24044,
#   'usertype': 'Subscriber',
#   'birth year': 1981,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.95852515, 40.7190095]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.94708417, 40.69957608]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 35, 6),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 55, 43)},
#  {'_id': ObjectId('572bb8222b288919b68ac006'),
#   'tripduration': 3244,
#   'start station id': 3175,
#   'start station name': 'W 70 St & Amsterdam Ave',
#   'end station id': 363,
#   'end station name': 'West Thames St',
#   'bikeid': 22181,
#   'usertype': 'Customer',
#   'birth year': '',
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.98288594, 40.77748046]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-74.01713445, 40.70834698]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 37, 12),
#   'stop time': datetime.datetime(2016, 1, 1, 1, 31, 17)},
#  {'_id': ObjectId('572bb8222b288919b68ac007'),
#   'tripduration': 1026,
#   'start station id': 430,
#   'start station name': 'York St & Jay St',
#   'end station id': 279,
#   'end station name': 'Peck Slip & Front St',
#   'bikeid': 18414,
#   'usertype': 'Subscriber',
#   'birth year': 1967,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.98656928, 40.7014851]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-74.00167, 40.707873]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 37, 16),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 54, 23)},
#  {'_id': ObjectId('572bb8222b288919b68ac00a'),
#   'tripduration': 384,
#   'start station id': 498,
#   'start station name': 'Broadway & W 32 St',
#   'end station id': 382,
#   'end station name': 'University Pl & E 14 St',
#   'bikeid': 17827,
#   'usertype': 'Subscriber',
#   'birth year': 1984,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.98808416, 40.74854862]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.99200509, 40.73492695]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 37, 53),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 44, 18)},
#  {'_id': ObjectId('572bb8222b288919b68ac00d'),
#   'tripduration': 255,
#   'start station id': 223,
#   'start station name': 'W 13 St & 7 Ave',
#   'end station id': 336,
#   'end station name': 'Sullivan St & Washington Sq',
#   'bikeid': 17073,
#   'usertype': 'Subscriber',
#   'birth year': 1985,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.99994661, 40.73781509]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.99906065, 40.73047747]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 38, 7),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 42, 23)},
#  {'_id': ObjectId('572bb8222b288919b68ac00e'),
#   'tripduration': 990,
#   'start station id': 238,
#   'start station name': 'Bank St & Washington St',
#   'end station id': 448,
#   'end station name': 'W 37 St & 10 Ave',
#   'bikeid': 22554,
#   'usertype': 'Subscriber',
#   'birth year': 1974,
#   'start station location': {'type': 'Point',
#    'coordinates': [-74.00859207, 40.7361967]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.9979009, 40.75660359]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 38, 8),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 54, 38)},
#  {'_id': ObjectId('572bb8222b288919b68ac012'),
#   'tripduration': 552,
#   'start station id': 3164,
#   'start station name': 'Columbus Ave & W 72 St',
#   'end station id': 3176,
#   'end station name': 'W 64 St & West End Ave',
#   'bikeid': 14957,
#   'usertype': 'Subscriber',
#   'birth year': 1969,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.97898475, 40.7770575]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.98753759, 40.77452835]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 38, 56),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 48, 9)},
#  {'_id': ObjectId('572bb8222b288919b68ac013'),
#   'tripduration': 774,
#   'start station id': 479,
#   'start station name': '9 Ave & W 45 St',
#   'end station id': 470,
#   'end station name': 'W 20 St & 8 Ave',
#   'bikeid': 20028,
#   'usertype': 'Subscriber',
#   'birth year': 1982,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.9912551, 40.76019252]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-74.00004031, 40.74345335]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 38, 57),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 51, 52)},
#  {'_id': ObjectId('572bb8222b288919b68ac019'),
#   'tripduration': 342,
#   'start station id': 426,
#   'start station name': 'West St & Chambers St',
#   'end station id': 2008,
#   'end station name': 'Little West St & 1 Pl',
#   'bikeid': 22772,
#   'usertype': 'Subscriber',
#   'birth year': 1977,
#   'start station location': {'type': 'Point',
#    'coordinates': [-74.01322069, 40.71754834]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-74.01677685, 40.70569254]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 39, 50),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 45, 33)},
#  {'_id': ObjectId('572bb8222b288919b68ac01b'),
#   'tripduration': 1057,
#   'start station id': 486,
#   'start station name': 'Broadway & W 29 St',
#   'end station id': 3164,
#   'end station name': 'Columbus Ave & W 72 St',
#   'bikeid': 22777,
#   'usertype': 'Subscriber',
#   'birth year': 1975,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.98855723, 40.7462009]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.97898475, 40.7770575]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 40, 13),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 57, 50)},
#  {'_id': ObjectId('572bb8222b288919b68ac01e'),
#   'tripduration': 789,
#   'start station id': 168,
#   'start station name': 'W 18 St & 6 Ave',
#   'end station id': 445,
#   'end station name': 'E 10 St & Avenue A',
#   'bikeid': 15774,
#   'usertype': 'Subscriber',
#   'birth year': 1984,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.99456405, 40.73971301]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.98142006, 40.72740794]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 41, 2),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 54, 11)},
#  {'_id': ObjectId('572bb8222b288919b68ac01f'),
#   'tripduration': 1047,
#   'start station id': 454,
#   'start station name': 'E 51 St & 1 Ave',
#   'end station id': 504,
#   'end station name': '1 Ave & E 15 St',
#   'bikeid': 22123,
#   'usertype': 'Subscriber',
#   'birth year': 1987,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.96592976, 40.75455731]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.98165557, 40.73221853]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 41, 16),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 58, 44)},
#  {'_id': ObjectId('572bb8222b288919b68ac020'),
#   'tripduration': 1033,
#   'start station id': 439,
#   'start station name': 'E 4 St & 2 Ave',
#   'end station id': 380,
#   'end station name': 'W 4 St & 7 Ave S',
#   'bikeid': 21683,
#   'usertype': 'Subscriber',
#   'birth year': 1970,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.98978041, 40.7262807]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-74.00293877, 40.73401143]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 41, 39),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 58, 52)},
#  {'_id': ObjectId('572bb8222b288919b68ac023'),
#   'tripduration': 905,
#   'start station id': 116,
#   'start station name': 'W 17 St & 8 Ave',
#   'end station id': 495,
#   'end station name': 'W 47 St & 10 Ave',
#   'bikeid': 21512,
#   'usertype': 'Subscriber',
#   'birth year': 1984,
#   'start station location': {'type': 'Point',
#    'coordinates': [-74.00149746, 40.74177603]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.99301222, 40.76269882]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 41, 59),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 57, 4)},
#  {'_id': ObjectId('572bb8222b288919b68ac027'),
#   'tripduration': 1444,
#   'start station id': 455,
#   'start station name': '1 Ave & E 44 St',
#   'end station id': 3156,
#   'end station name': 'E 72 St & York Ave',
#   'bikeid': 19976,
#   'usertype': 'Customer',
#   'birth year': '',
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.96905301, 40.75001986]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.95348296, 40.76663814]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 43, 37),
#   'stop time': datetime.datetime(2016, 1, 1, 1, 7, 42)},
#  {'_id': ObjectId('572bb8222b288919b68ac032'),
#   'tripduration': 1447,
#   'start station id': 455,
#   'start station name': '1 Ave & E 44 St',
#   'end station id': 3156,
#   'end station name': 'E 72 St & York Ave',
#   'bikeid': 21034,
#   'usertype': 'Customer',
#   'birth year': '',
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.96905301, 40.75001986]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.95348296, 40.76663814]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 44, 32),
#   'stop time': datetime.datetime(2016, 1, 1, 1, 8, 40)},
#  {'_id': ObjectId('572bb8222b288919b68ac035'),
#   'tripduration': 525,
#   'start station id': 344,
#   'start station name': 'Monroe St & Bedford Ave',
#   'end station id': 3060,
#   'end station name': 'Willoughby Ave & Tompkins Ave',
#   'bikeid': 22920,
#   'usertype': 'Subscriber',
#   'birth year': 1977,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.95380904, 40.6851443]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.94626915, 40.69425403]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 45, 14),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 54)},
#  {'_id': ObjectId('572bb8222b288919b68ac03e'),
#   'tripduration': 3049,
#   'start station id': 3103,
#   'start station name': 'N 11 St & Wythe Ave',
#   'end station id': 308,
#   'end station name': 'St James Pl & Oliver St',
#   'bikeid': 23273,
#   'usertype': 'Customer',
#   'birth year': '',
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.95782357, 40.72153267]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.99851193, 40.71307916]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 45, 50),
#   'stop time': datetime.datetime(2016, 1, 1, 1, 36, 39)},
#  {'_id': ObjectId('572bb8222b288919b68abf5a'),
#   'tripduration': 379,
#   'start station id': 476,
#   'start station name': 'E 31 St & 3 Ave',
#   'end station id': 498,
#   'end station name': 'Broadway & W 32 St',
#   'bikeid': 17827,
#   'usertype': 'Subscriber',
#   'birth year': 1969,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.97966069, 40.74394314]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.98808416, 40.74854862]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 0, 45),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 7, 4)},
#  {'_id': ObjectId('572bb8222b288919b68abf5d'),
#   'tripduration': 923,
#   'start station id': 268,
#   'start station name': 'Howard St & Centre St',
#   'end station id': 3002,
#   'end station name': 'South End Ave & Liberty St',
#   'bikeid': 22285,
#   'usertype': 'Subscriber',
#   'birth year': 1958,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.99973337, 40.71910537]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-74.015756, 40.711512]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 0, 41),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 16, 4)},
#  {'_id': ObjectId('572bb8222b288919b68abf65'),
#   'tripduration': 525,
#   'start station id': 331,
#   'start station name': 'Pike St & Monroe St',
#   'end station id': 236,
#   'end station name': 'St Marks Pl & 2 Ave',
#   'bikeid': 22193,
#   'usertype': 'Subscriber',
#   'birth year': 1988,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.99193043, 40.71173107]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.98713956, 40.7284186]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 5, 40),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 14, 25)},
#  {'_id': ObjectId('572bb8222b288919b68abf66'),
#   'tripduration': 667,
#   'start station id': 444,
#   'start station name': 'Broadway & W 24 St',
#   'end station id': 490,
#   'end station name': '8 Ave & W 33 St',
#   'bikeid': 18665,
#   'usertype': 'Subscriber',
#   'birth year': 1964,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.98915076, 40.7423543]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.993934, 40.751551]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 5, 41),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 16, 49)},
#  {'_id': ObjectId('572bb8222b288919b68abf69'),
#   'tripduration': 1245,
#   'start station id': 442,
#   'start station name': 'W 27 St & 7 Ave',
#   'end station id': 545,
#   'end station name': 'E 23 St & 1 Ave',
#   'bikeid': 24071,
#   'usertype': 'Subscriber',
#   'birth year': 1970,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.993915, 40.746647]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.97809472, 40.736502]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 8, 17),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 29, 3)},
#  {'_id': ObjectId('572bb8222b288919b68abf70'),
#   'tripduration': 110,
#   'start station id': 439,
#   'start station name': 'E 4 St & 2 Ave',
#   'end station id': 439,
#   'end station name': 'E 4 St & 2 Ave',
#   'bikeid': 24021,
#   'usertype': 'Customer',
#   'birth year': '',
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.98978041, 40.7262807]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.98978041, 40.7262807]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 10, 24),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 12, 15)},
#  {'_id': ObjectId('572bb8222b288919b68abf74'),
#   'tripduration': 2023,
#   'start station id': 3143,
#   'start station name': '5 Ave & E 78 St',
#   'end station id': 479,
#   'end station name': '9 Ave & W 45 St',
#   'bikeid': 14769,
#   'usertype': 'Customer',
#   'birth year': '',
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.96388769149779, 40.77682863439968]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.9912551, 40.76019252]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 11, 15),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 44, 58)},
#  {'_id': ObjectId('572bb8222b288919b68abf75'),
#   'tripduration': 743,
#   'start station id': 531,
#   'start station name': 'Forsyth St & Broome St',
#   'end station id': 2003,
#   'end station name': '1 Ave & E 18 St',
#   'bikeid': 21624,
#   'usertype': 'Subscriber',
#   'birth year': 1970,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.99266288, 40.71893904]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.98054420948029, 40.733812191966315]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 11, 42),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 24, 5)},
#  {'_id': ObjectId('572bb8222b288919b68abf77'),
#   'tripduration': 662,
#   'start station id': 3175,
#   'start station name': 'W 70 St & Amsterdam Ave',
#   'end station id': 3166,
#   'end station name': 'Riverside Dr & W 72 St',
#   'bikeid': 22560,
#   'usertype': 'Subscriber',
#   'birth year': 1976,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.98288594, 40.77748046]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.98562431335449, 40.78057799010334]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 12, 16),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 23, 19)},
#  {'_id': ObjectId('572bb8222b288919b68abf78'),
#   'tripduration': 1169,
#   'start station id': 517,
#   'start station name': 'Pershing Square South',
#   'end station id': 237,
#   'end station name': 'E 11 St & 2 Ave',
#   'bikeid': 19424,
#   'usertype': 'Customer',
#   'birth year': '',
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.97791, 40.751581]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.98672378, 40.73047309]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 12, 31),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 32, 1)},
#  {'_id': ObjectId('572bb8222b288919b68abf79'),
#   'tripduration': 1167,
#   'start station id': 517,
#   'start station name': 'Pershing Square South',
#   'end station id': 237,
#   'end station name': 'E 11 St & 2 Ave',
#   'bikeid': 14823,
#   'usertype': 'Customer',
#   'birth year': '',
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.97791, 40.751581]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.98672378, 40.73047309]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 12, 35),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 32, 3)},
#  {'_id': ObjectId('572bb8222b288919b68abf7e'),
#   'tripduration': 557,
#   'start station id': 363,
#   'start station name': 'West Thames St',
#   'end station id': 146,
#   'end station name': 'Hudson St & Reade St',
#   'bikeid': 17569,
#   'usertype': 'Subscriber',
#   'birth year': 1960,
#   'start station location': {'type': 'Point',
#    'coordinates': [-74.01713445, 40.70834698]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-74.0091059, 40.71625008]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 13, 30),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 22, 47)},
#  {'_id': ObjectId('572bb8222b288919b68abf7f'),
#   'tripduration': 272,
#   'start station id': 3002,
#   'start station name': 'South End Ave & Liberty St',
#   'end station id': 264,
#   'end station name': 'Maiden Ln & Pearl St',
#   'bikeid': 21619,
#   'usertype': 'Subscriber',
#   'birth year': 1989,
#   'start station location': {'type': 'Point',
#    'coordinates': [-74.015756, 40.711512]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-74.00731853, 40.70706456]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 13, 45),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 18, 17)},
#  {'_id': ObjectId('572bb8222b288919b68abf86'),
#   'tripduration': 1087,
#   'start station id': 280,
#   'start station name': 'E 10 St & 5 Ave',
#   'end station id': 527,
#   'end station name': 'E 33 St & 2 Ave',
#   'bikeid': 20945,
#   'usertype': 'Subscriber',
#   'birth year': 1990,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.99510132, 40.73331967]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.976056, 40.744023]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 16, 8),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 34, 15)},
#  {'_id': ObjectId('572bb8222b288919b68abf87'),
#   'tripduration': 960,
#   'start station id': 492,
#   'start station name': 'W 33 St & 7 Ave',
#   'end station id': 405,
#   'end station name': 'Washington St & Gansevoort St',
#   'bikeid': 19039,
#   'usertype': 'Subscriber',
#   'birth year': 1982,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.99093085, 40.75019995]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-74.008119, 40.739323]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 16, 13),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 32, 13)},
#  {'_id': ObjectId('572bb8222b288919b68abf8c'),
#   'tripduration': 2595,
#   'start station id': 485,
#   'start station name': 'W 37 St & 5 Ave',
#   'end station id': 281,
#   'end station name': 'Grand Army Plaza & Central Park S',
#   'bikeid': 15861,
#   'usertype': 'Subscriber',
#   'birth year': 1988,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.98338988, 40.75038009]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.97371465, 40.7643971]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 17, 4),
#   'stop time': datetime.datetime(2016, 1, 1, 1, 0, 19)},
#  {'_id': ObjectId('572bb8222b288919b68abf8f'),
#   'tripduration': 1485,
#   'start station id': 369,
#   'start station name': 'Washington Pl & 6 Ave',
#   'end station id': 442,
#   'end station name': 'W 27 St & 7 Ave',
#   'bikeid': 18112,
#   'usertype': 'Customer',
#   'birth year': '',
#   'start station location': {'type': 'Point',
#    'coordinates': [-74.00026394, 40.73224119]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.993915, 40.746647]},
#   'start time': datetime.datetime(2016, 1, 1, 0, 17, 24),
#   'stop time': datetime.datetime(2016, 1, 1, 0, 42, 10)},
#  {'_id': ObjectId('572bb8222b288919b68abf90'),
#   'tripduration': 667,
#   'start station id': 461,
#   'start station name': 'E 20 St & 2 Ave',
#   'end station id': 494,
# ...
#   'start time': datetime.datetime(2016, 1, 1, 2, 46, 35),
#   'stop time': datetime.datetime(2016, 1, 1, 2, 55, 44)},
#  {'_id': ObjectId('572bb8222b288919b68ac2e8'),
#   'tripduration': 1206,
#   'start station id': 459,
#   'start station name': 'W 20 St & 11 Ave',
#   'end station id': 427,
#   'end station name': 'Bus Slip & State St',
#   'bikeid': 22074,
#   'usertype': 'Subscriber',
#   'birth year': 1989,
#   'start station location': {'type': 'Point',
#    'coordinates': [-74.007756, 40.746745]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-74.013942, 40.701907]},
#   'start time': datetime.datetime(2016, 1, 1, 2, 48, 13),
#   'stop time': datetime.datetime(2016, 1, 1, 3, 8, 20)},
#  {'_id': ObjectId('572bb8222b288919b68ac2ea'),
#   'tripduration': 666,
#   'start station id': 151,
#   'start station name': 'Cleveland Pl & Spring St',
#   'end station id': 345,
#   'end station name': 'W 13 St & 6 Ave',
#   'bikeid': 23643,
#   'usertype': 'Subscriber',
#   'birth year': 1952,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.99724900722504, 40.722103786686034]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.99704374, 40.73649403]},
#   'start time': datetime.datetime(2016, 1, 1, 2, 48, 31),
#   'stop time': datetime.datetime(2016, 1, 1, 2, 59, 38)},
#  {'_id': ObjectId('572bb8222b288919b68ac2ed'),
#   'tripduration': 240,
#   'start station id': 3062,
#   'start station name': 'Myrtle Ave & Marcy Ave',
#   'end station id': 3057,
#   'end station name': 'Kosciuszko St & Tompkins Ave',
#   'bikeid': 17728,
#   'usertype': 'Subscriber',
#   'birth year': 1984,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.94954908, 40.69539817]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.9452416, 40.69128258]},
#   'start time': datetime.datetime(2016, 1, 1, 2, 49, 16),
#   'stop time': datetime.datetime(2016, 1, 1, 2, 53, 16)},
#  {'_id': ObjectId('572bb8222b288919b68ac2f0'),
#   'tripduration': 219,
#   'start station id': 3062,
#   'start station name': 'Myrtle Ave & Marcy Ave',
#   'end station id': 3057,
#   'end station name': 'Kosciuszko St & Tompkins Ave',
#   'bikeid': 19703,
#   'usertype': 'Subscriber',
#   'birth year': 1984,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.94954908, 40.69539817]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.9452416, 40.69128258]},
#   'start time': datetime.datetime(2016, 1, 1, 2, 49, 42),
#   'stop time': datetime.datetime(2016, 1, 1, 2, 53, 21)},
#  {'_id': ObjectId('572bb8222b288919b68ac2f4'),
#   'tripduration': 196,
#   'start station id': 439,
#   'start station name': 'E 4 St & 2 Ave',
#   'end station id': 483,
#   'end station name': 'E 12 St & 3 Ave',
#   'bikeid': 15385,
#   'usertype': 'Subscriber',
#   'birth year': 1987,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.98978041, 40.7262807]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.98889957, 40.73223272]},
#   'start time': datetime.datetime(2016, 1, 1, 2, 50, 39),
#   'stop time': datetime.datetime(2016, 1, 1, 2, 53, 56)},
#  {'_id': ObjectId('572bb8222b288919b68ac2f5'),
#   'tripduration': 249,
#   'start station id': 304,
#   'start station name': 'Broadway & Battery Pl',
#   'end station id': 363,
#   'end station name': 'West Thames St',
#   'bikeid': 20727,
#   'usertype': 'Subscriber',
#   'birth year': 1991,
#   'start station location': {'type': 'Point',
#    'coordinates': [-74.01361706, 40.70463334]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-74.01713445, 40.70834698]},
#   'start time': datetime.datetime(2016, 1, 1, 2, 50, 41),
#   'stop time': datetime.datetime(2016, 1, 1, 2, 54, 50)},
#  {'_id': ObjectId('572bb8222b288919b68ac2f7'),
#   'tripduration': 788,
#   'start station id': 293,
#   'start station name': 'Lafayette St & E 8 St',
#   'end station id': 296,
#   'end station name': 'Division St & Bowery',
#   'bikeid': 19644,
#   'usertype': 'Subscriber',
#   'birth year': 1992,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.9907647, 40.73028666]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.9970468, 40.71413089]},
#   'start time': datetime.datetime(2016, 1, 1, 2, 51),
#   'stop time': datetime.datetime(2016, 1, 1, 3, 4, 9)},
#  {'_id': ObjectId('572bb8222b288919b68ac2f8'),
#   'tripduration': 782,
#   'start station id': 293,
#   'start station name': 'Lafayette St & E 8 St',
#   'end station id': 296,
#   'end station name': 'Division St & Bowery',
#   'bikeid': 23310,
#   'usertype': 'Subscriber',
#   'birth year': 1992,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.9907647, 40.73028666]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.9970468, 40.71413089]},
#   'start time': datetime.datetime(2016, 1, 1, 2, 51, 3),
#   'stop time': datetime.datetime(2016, 1, 1, 3, 4, 6)},
#  {'_id': ObjectId('572bb8222b288919b68ac2fb'),
#   'tripduration': 2787,
#   'start station id': 83,
#   'start station name': 'Atlantic Ave & Fort Greene Pl',
#   'end station id': 225,
#   'end station name': 'W 14 St & The High Line',
#   'bikeid': 19656,
#   'usertype': 'Subscriber',
#   'birth year': 1983,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.97632328, 40.68382604]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-74.00803013, 40.74195138]},
#   'start time': datetime.datetime(2016, 1, 1, 2, 51, 47),
#   'stop time': datetime.datetime(2016, 1, 1, 3, 38, 14)},
#  {'_id': ObjectId('572bb8222b288919b68ac2ff'),
#   'tripduration': 390,
#   'start station id': 396,
#   'start station name': 'Lefferts Pl & Franklin Ave',
#   'end station id': 120,
#   'end station name': 'Lexington Ave & Classon Ave',
#   'bikeid': 23694,
#   'usertype': 'Subscriber',
#   'birth year': 1985,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.9557689392, 40.680342423]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.95928168, 40.68676793]},
#   'start time': datetime.datetime(2016, 1, 1, 2, 52, 39),
#   'stop time': datetime.datetime(2016, 1, 1, 2, 59, 9)},
#  {'_id': ObjectId('572bb8222b288919b68ac302'),
#   'tripduration': 193,
#   'start station id': 293,
#   'start station name': 'Lafayette St & E 8 St',
#   'end station id': 336,
#   'end station name': 'Sullivan St & Washington Sq',
#   'bikeid': 17982,
#   'usertype': 'Subscriber',
#   'birth year': 1994,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.9907647, 40.73028666]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.99906065, 40.73047747]},
#   'start time': datetime.datetime(2016, 1, 1, 2, 53, 39),
#   'stop time': datetime.datetime(2016, 1, 1, 2, 56, 53)},
#  {'_id': ObjectId('572bb8222b288919b68ac305'),
#   'tripduration': 365,
#   'start station id': 265,
#   'start station name': 'Stanton St & Chrystie St',
#   'end station id': 237,
#   'end station name': 'E 11 St & 2 Ave',
#   'bikeid': 23413,
#   'usertype': 'Subscriber',
#   'birth year': 1981,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.99147535, 40.72229346]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.98672378, 40.73047309]},
#   'start time': datetime.datetime(2016, 1, 1, 2, 54, 7),
#   'stop time': datetime.datetime(2016, 1, 1, 3, 0, 12)},
#  {'_id': ObjectId('572bb8222b288919b68ac30e'),
#   'tripduration': 98,
#   'start station id': 433,
#   'start station name': 'E 13 St & Avenue A',
#   'end station id': 432,
#   'end station name': 'E 7 St & Avenue A',
#   'bikeid': 22955,
#   'usertype': 'Subscriber',
#   'birth year': 1983,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.98057249, 40.72955361]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.98379855, 40.72621788]},
#   'start time': datetime.datetime(2016, 1, 1, 2, 57, 25),
#   'stop time': datetime.datetime(2016, 1, 1, 2, 59, 3)},
#  {'_id': ObjectId('572bb8222b288919b68ac315'),
#   'tripduration': 202,
#   'start station id': 3222,
#   'start station name': 'Hanson Pl & St Felix St',
#   'end station id': 420,
#   'end station name': 'Clermont Ave & Lafayette Ave',
#   'bikeid': 22156,
#   'usertype': 'Subscriber',
#   'birth year': 1989,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.97711366415024, 40.685159599891776]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.96968902, 40.68764484]},
#   'start time': datetime.datetime(2016, 1, 1, 3, 0, 32),
#   'stop time': datetime.datetime(2016, 1, 1, 3, 3, 55)},
#  {'_id': ObjectId('572bb8222b288919b68ac31a'),
#   'tripduration': 391,
#   'start station id': 448,
#   'start station name': 'W 37 St & 10 Ave',
#   'end station id': 486,
#   'end station name': 'Broadway & W 29 St',
#   'bikeid': 23116,
#   'usertype': 'Subscriber',
#   'birth year': 1971,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.9979009, 40.75660359]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.98855723, 40.7462009]},
#   'start time': datetime.datetime(2016, 1, 1, 3, 0, 59),
#   'stop time': datetime.datetime(2016, 1, 1, 3, 7, 30)},
#  {'_id': ObjectId('572bb8222b288919b68ac31b'),
#   'tripduration': 575,
#   'start station id': 250,
#   'start station name': 'Lafayette St & Jersey St',
#   'end station id': 432,
#   'end station name': 'E 7 St & Avenue A',
#   'bikeid': 23788,
#   'usertype': 'Subscriber',
#   'birth year': 1984,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.99565293, 40.72456089]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.98379855, 40.72621788]},
#   'start time': datetime.datetime(2016, 1, 1, 3, 1, 32),
#   'stop time': datetime.datetime(2016, 1, 1, 3, 11, 7)},
#  {'_id': ObjectId('572bb8222b288919b68ac31c'),
#   'tripduration': 901,
#   'start station id': 405,
#   'start station name': 'Washington St & Gansevoort St',
#   'end station id': 473,
#   'end station name': 'Rivington St & Chrystie St',
#   'bikeid': 19039,
#   'usertype': 'Subscriber',
#   'birth year': 1976,
#   'start station location': {'type': 'Point',
#    'coordinates': [-74.008119, 40.739323]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.9919254, 40.72110063]},
#   'start time': datetime.datetime(2016, 1, 1, 3, 1, 57),
#   'stop time': datetime.datetime(2016, 1, 1, 3, 16, 59)},
#  {'_id': ObjectId('572bb8222b288919b68ac31e'),
#   'tripduration': 364,
#   'start station id': 474,
#   'start station name': '5 Ave & E 29 St',
#   'end station id': 402,
#   'end station name': 'Broadway & E 22 St',
#   'bikeid': 21254,
#   'usertype': 'Subscriber',
#   'birth year': 1986,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.98683077, 40.7451677]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.98955109, 40.7403432]},
#   'start time': datetime.datetime(2016, 1, 1, 3, 2, 31),
#   'stop time': datetime.datetime(2016, 1, 1, 3, 8, 35)},
#  {'_id': ObjectId('572bb8222b288919b68ac323'),
#   'tripduration': 561,
#   'start station id': 485,
#   'start station name': 'W 37 St & 5 Ave',
#   'end station id': 489,
#   'end station name': '10 Ave & W 28 St',
#   'bikeid': 23762,
#   'usertype': 'Subscriber',
#   'birth year': 1980,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.98338988, 40.75038009]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-74.00176802, 40.75066386]},
#   'start time': datetime.datetime(2016, 1, 1, 3, 3, 40),
#   'stop time': datetime.datetime(2016, 1, 1, 3, 13, 1)},
#  {'_id': ObjectId('572bb8222b288919b68ac326'),
#   'tripduration': 322,
#   'start station id': 257,
#   'start station name': 'Lispenard St & Broadway',
#   'end station id': 473,
#   'end station name': 'Rivington St & Chrystie St',
#   'bikeid': 14743,
#   'usertype': 'Subscriber',
#   'birth year': 1976,
#   'start station location': {'type': 'Point',
#    'coordinates': [-74.00247214, 40.71939226]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.9919254, 40.72110063]},
#   'start time': datetime.datetime(2016, 1, 1, 3, 4, 6),
#   'stop time': datetime.datetime(2016, 1, 1, 3, 9, 29)},
#  {'_id': ObjectId('572bb8222b288919b68ac329'),
#   'tripduration': 595,
#   'start station id': 497,
#   'start station name': 'E 17 St & Broadway',
#   'end station id': 161,
#   'end station name': 'LaGuardia Pl & W 3 St',
#   'bikeid': 18952,
#   'usertype': 'Subscriber',
#   'birth year': 1953,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.99009296, 40.73704984]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.99810231, 40.72917025]},
#   'start time': datetime.datetime(2016, 1, 1, 3, 4, 51),
#   'stop time': datetime.datetime(2016, 1, 1, 3, 14, 47)},
#  {'_id': ObjectId('572bb8222b288919b68ac32e'),
#   'tripduration': 302,
#   'start station id': 3079,
#   'start station name': 'Leonard St & Grand St',
#   'end station id': 3066,
#   'end station name': 'Tompkins Ave & Hopkins St',
#   'bikeid': 22147,
#   'usertype': 'Subscriber',
#   'birth year': 1973,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.94714303, 40.71103537]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.94708417, 40.69957608]},
#   'start time': datetime.datetime(2016, 1, 1, 3, 5, 41),
#   'stop time': datetime.datetime(2016, 1, 1, 3, 10, 44)},
#  {'_id': ObjectId('572bb8222b288919b68ac331'),
#   'tripduration': 1333,
#   'start station id': 250,
#   'start station name': 'Lafayette St & Jersey St',
#   'end station id': 517,
#   'end station name': 'Pershing Square South',
#   'bikeid': 23795,
#   'usertype': 'Customer',
#   'birth year': '',
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.99565293, 40.72456089]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.97791, 40.751581]},
#   'start time': datetime.datetime(2016, 1, 1, 3, 6, 15),
#   'stop time': datetime.datetime(2016, 1, 1, 3, 28, 28)},
#  {'_id': ObjectId('572bb8222b288919b68ac332'),
#   'tripduration': 125,
#   'start station id': 377,
#   'start station name': '6 Ave & Canal St',
#   'end station id': 2010,
#   'end station name': 'Grand St & Greene St',
#   'bikeid': 20146,
#   'usertype': 'Subscriber',
#   'birth year': 1991,
#   'start station location': {'type': 'Point',
#    'coordinates': [-74.00566443, 40.72243797]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-74.00234737, 40.72165481]},
#   'start time': datetime.datetime(2016, 1, 1, 3, 3, 44),
#   'stop time': datetime.datetime(2016, 1, 1, 3, 5, 50)},
#  {'_id': ObjectId('572bb8222b288919b68ac339'),
#   'tripduration': 414,
#   'start station id': 494,
#   'start station name': 'W 26 St & 8 Ave',
#   'end station id': 529,
#   'end station name': 'W 42 St & 8 Ave',
#   'bikeid': 18356,
#   'usertype': 'Subscriber',
#   'birth year': 1989,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.99723551, 40.74734825]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.99098507, 40.7575699]},
#   'start time': datetime.datetime(2016, 1, 1, 3, 6, 58),
#   'stop time': datetime.datetime(2016, 1, 1, 3, 13, 52)},
#  {'_id': ObjectId('572bb8222b288919b68ac33a'),
#   'tripduration': 266,
#   'start station id': 3107,
#   'start station name': 'Bedford Ave & Nassau Ave',
#   'end station id': 3093,
#   'end station name': 'N 6 St & Bedford Ave',
#   'bikeid': 22762,
#   'usertype': 'Subscriber',
#   'birth year': 1983,
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.95212324, 40.72311651]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.95850939, 40.71745169]},
#   'start time': datetime.datetime(2016, 1, 1, 3, 7, 6),
#   'stop time': datetime.datetime(2016, 1, 1, 3, 11, 32)},
#  {'_id': ObjectId('572bb8222b288919b68ac33e'),
#   'tripduration': 394,
#   'start station id': 400,
#   'start station name': 'Pitt St & Stanton St',
#   'end station id': 428,
#   'end station name': 'E 3 St & 1 Ave',
#   'bikeid': 17609,
#   'usertype': 'Customer',
#   'birth year': '',
#   'start station location': {'type': 'Point',
#    'coordinates': [-73.98178024, 40.71926081]},
#   'end station location': {'type': 'Point',
#    'coordinates': [-73.98783413, 40.72467721]},
#   'start time': datetime.datetime(2016, 1, 1, 3, 7, 32),
#   'stop time': datetime.datetime(2016, 1, 1, 3, 14, 6)},
#  ...]

# %%
trip = db.trips.find()

# %%
df_trips = pd.DataFrame(trip)

# %%
df_trips.head()
# Out:
#                         _id  tripduration  start station id  \
# 0  572bb8222b288919b68abf5c           589               489
# 1  572bb8222b288919b68abf61          1376               527
# 2  572bb8222b288919b68abf63           615               432
# 3  572bb8222b288919b68abf64          1770              3226
# 4  572bb8222b288919b68abf6e           719              3116
#
#             start station name  end station id         end station name  \
# 0             10 Ave & W 28 St             284    Greenwich Ave & 8 Ave
# 1              E 33 St & 2 Ave             259  South St & Whitehall St
# 2            E 7 St & Avenue A             311   Norfolk St & Broome St
# 3  W 82 St & Central Park West             509          9 Ave & W 22 St
# 4       Huron St & Franklin St            3126      44 Dr & Jackson Ave
#
#    bikeid    usertype birth year  \
# 0   21997  Subscriber       1982
# 1   23933  Subscriber       1963
# 2   23993  Subscriber       1971
# 3   22541  Subscriber       1970
# 4   16624  Subscriber       1982
#
#                               start station location  \
# 0  {'type': 'Point', 'coordinates': [-74.00176802...
# 1  {'type': 'Point', 'coordinates': [-73.976056, ...
# 2  {'type': 'Point', 'coordinates': [-73.98379855...
# 3  {'type': 'Point', 'coordinates': [-73.97137, 4...
# 4  {'type': 'Point', 'coordinates': [-73.95826, 4...
#
#                                 end station location          start time  \
# 0  {'type': 'Point', 'coordinates': [-74.00263761... 2016-01-01 00:00:48
# 1  {'type': 'Point', 'coordinates': [-74.01234218... 2016-01-01 00:03:12
# 2  {'type': 'Point', 'coordinates': [-73.98802084... 2016-01-01 00:03:43
# 3  {'type': 'Point', 'coordinates': [-74.00197139... 2016-01-01 00:04:43
# 4  {'type': 'Point', 'coordinates': [-73.9432635,... 2016-01-01 00:10:00
#
#             stop time
# 0 2016-01-01 00:10:37
# 1 2016-01-01 00:26:09
# 2 2016-01-01 00:13:59
# 3 2016-01-01 00:34:14
# 4 2016-01-01 00:21:59

# %%
df_trips['usertype']
# Out:
# 0       Subscriber
# 1       Subscriber
# 2       Subscriber
# 3       Subscriber
# 4       Subscriber
#            ...
# 9995    Subscriber
# 9996    Subscriber
# 9997      Customer
# 9998    Subscriber
# 9999    Subscriber
# Name: usertype, Length: 10000, dtype: object

# %%
df_trips.iloc[0]
# Out:
# _id                                                572bb8222b288919b68abf5c
# tripduration                                                            589
# start station id                                                        489
# start station name                                         10 Ave & W 28 St
# end station id                                                          284
# end station name                                      Greenwich Ave & 8 Ave
# bikeid                                                                21997
# usertype                                                         Subscriber
# birth year                                                             1982
# start station location    {'type': 'Point', 'coordinates': [-74.00176802...
# end station location      {'type': 'Point', 'coordinates': [-74.00263761...
# start time                                              2016-01-01 00:00:48
# stop time                                               2016-01-01 00:10:37
# Name: 0, dtype: object

# %%
df_trips.iloc[0]['start station location']['coordinates']
# Out:
# [-74.00176802, 40.75066386]

# %%
[point['coordinates'] for point in df_trips['start station location']]
# Out:
# [[-74.00176802, 40.75066386],
#  [-73.976056, 40.744023],
#  [-73.98379855, 40.72621788],
#  [-73.97137, 40.78275],
#  [-73.95826, 40.73266],
#  [-73.99839279, 40.7500727],
#  [-74.0046073, 40.71273266],
#  [-73.96592080593109, 40.76780080148132],
#  [-73.9734419, 40.74780373],
#  [-73.99595065, 40.69512845],
#  [-73.98602213, 40.74096374],
#  [-73.99510132, 40.73331967],
#  [-73.99093085, 40.75019995],
#  [-73.97371465, 40.7643971],
#  [-73.98990025, 40.71427487],
#  [-74.00026394, 40.73224119],
#  [-73.98783413, 40.72467721],
#  [-73.98889957, 40.73223272],
#  [-73.98889957, 40.73223272],
#  [-73.98142006, 40.72740794],
#  [-73.97782542, 40.7734066],
#  [-74.00167, 40.707873],
#  [-74.00711384, 40.73291553],
#  [-73.99839279, 40.7500727],
#  [-73.96388769149779, 40.77682863439968],
#  [-73.99383605, 40.70277159],
#  [-73.96685276, 40.77282817],
#  [-73.95621, 40.72606],
#  [-73.96685276, 40.77282817],
#  [-73.95451, 40.74731],
#  [-74.00722156, 40.70862144],
#  [-73.99461843, 40.76009437],
#  [-74.00167, 40.707873],
#  [-73.97898475, 40.7770575],
#  [-73.99383605, 40.70277159],
#  [-73.97722479, 40.76340613],
#  [-73.98789473, 40.76461837],
#  [-73.98191841, 40.76915505],
#  [-73.9762057363987, 40.77579376683666],
#  [-73.977112, 40.7867947],
#  [-73.98142006, 40.72740794],
#  [-73.98409214, 40.74025878],
#  [-73.98859651, 40.75929124],
#  [-73.99461843, 40.76009437],
#  [-74.00154702, 40.72490985],
#  [-74.00004031, 40.74345335],
#  [-73.98672378, 40.73047309],
#  [-73.95852515, 40.7190095],
#  [-73.98288594, 40.77748046],
#  [-73.98656928, 40.7014851],
#  [-73.98808416, 40.74854862],
#  [-73.99994661, 40.73781509],
#  [-74.00859207, 40.7361967],
#  [-73.97898475, 40.7770575],
#  [-73.9912551, 40.76019252],
#  [-74.01322069, 40.71754834],
#  [-73.98855723, 40.7462009],
#  [-73.99456405, 40.73971301],
#  [-73.96592976, 40.75455731],
#  [-73.98978041, 40.7262807],
#  [-74.00149746, 40.74177603],
#  [-73.96905301, 40.75001986],
#  [-73.96905301, 40.75001986],
#  [-73.95380904, 40.6851443],
#  [-73.95782357, 40.72153267],
#  [-73.97966069, 40.74394314],
#  [-73.99973337, 40.71910537],
#  [-73.99193043, 40.71173107],
#  [-74.005226, 40.751396],
#  [-73.98672378, 40.73047309],
#  [-74.005549, 40.717571],
#  [-73.98165557, 40.73221853],
#  [-73.95982218, 40.70925562],
#  [-73.98564945, 40.72779126],
#  [-73.99069656, 40.72502876],
#  [-73.98978041, 40.7262807],
#  [-73.98379855, 40.72621788],
#  [-74.00965965, 40.72405549],
#  [-73.99238967, 40.73726186],
#  [-73.981346, 40.714215],
#  [-73.99069656, 40.72502876],
#  [-74.00653609, 40.70955958],
#  [-73.952029, 40.7160751],
#  [-73.95212324, 40.72311651],
#  [-73.97668709, 40.72228087],
#  [-73.99915362, 40.74475148],
#  [-73.99074142, 40.73454567],
#  [-73.9614583, 40.68223166],
#  [-73.97966069, 40.74394314],
#  [-73.99009296, 40.73704984],
#  [-73.963198, 40.716887],
#  [-74.00618026, 40.73652889],
#  [-74.0046073, 40.71273266],
#  [-73.98362492, 40.78414472],
#  [-73.98142006, 40.72740794],
#  [-73.97898475, 40.7770575],
#  [-73.97371465, 40.7643971],
#  [-74.0026376103, 40.7390169121],
#  [-73.979382, 40.688226],
#  [-73.963198, 40.716887],
#  [-73.94803392, 40.77536905],
#  [-74.01677685, 40.70569254],
#  [-73.9907647, 40.73028666],
#  [-73.94803392, 40.77536905],
#  [-73.98889957, 40.73223272],
#  [-74.009447, 40.711066],
#  [-74.007756, 40.746745],
#  [-73.99724900722504, 40.722103786686034],
#  [-73.94954908, 40.69539817],
#  [-73.94954908, 40.69539817],
#  [-73.98978041, 40.7262807],
#  [-74.01361706, 40.70463334],
#  [-73.9907647, 40.73028666],
#  [-73.9907647, 40.73028666],
#  [-73.97632328, 40.68382604],
#  [-73.9557689392, 40.680342423],
#  [-73.9907647, 40.73028666],
#  [-73.99147535, 40.72229346],
#  [-73.98057249, 40.72955361],
#  [-73.97711366415024, 40.685159599891776],
#  [-73.9979009, 40.75660359],
#  [-73.99565293, 40.72456089],
#  [-74.008119, 40.739323],
#  [-73.98683077, 40.7451677],
#  [-73.98338988, 40.75038009],
#  [-74.00247214, 40.71939226],
#  [-73.99009296, 40.73704984],
#  [-73.94714303, 40.71103537],
#  [-73.99565293, 40.72456089],
#  [-74.00566443, 40.72243797],
#  [-73.99723551, 40.74734825],
#  [-73.95212324, 40.72311651],
#  [-73.98178024, 40.71926081],
#  ...]

# %%
df = pd.DataFrame([pd.Series(point['coordinates'],index=['lat','long']) for point in df_trips['start station location']], columns=['lat','long'])

# %%
df
# Out:
#             lat       long
# 0    -73.979661  40.743943
# 1    -73.999733  40.719105
# 2    -74.001768  40.750664
# 3    -73.999733  40.719105
# 4    -73.961502  40.720577
# ...         ...        ...
# 9995 -73.993915  40.746647
# 9996 -73.985649  40.727791
# 9997 -73.960940  40.761227
# 9998 -73.984092  40.740259
# 9999 -73.986831  40.745168
#
# [10000 rows x 2 columns]

# %%
(df_trips['tripduration'] // 60 )> 10
# Out:
# 0       False
# 1        True
# 2       False
# 3        True
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999     True
# Name: tripduration, Length: 10000, dtype: bool
